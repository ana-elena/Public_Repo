# %% [markdown]
# # Web scrapping PAP data for PARIS flats rentals on Sept 13th

# %%
import requests 
from bs4 import BeautifulSoup
import time

# %%
headers= {'Cookie': 'lang=fr; acceptcookies=1; nb_resultats_par_page=10; derniere_recherche=%7B%22produit%22%3A%22location%22%2C%22typesbien%22%3A%5B%22appartement%22%5D%2C%22nb_pieces%22%3A%7B%22min%22%3Anull%2C%22max%22%3Anull%7D%2C%22nb_chambres%22%3A%7B%22min%22%3Anull%2C%22max%22%3Anull%7D%2C%22prix%22%3A%7B%22min%22%3Anull%2C%22max%22%3Anull%7D%2C%22surface%22%3A%7B%22min%22%3Anull%2C%22max%22%3Anull%7D%2C%22surface_terrain%22%3A%7B%22min%22%3Anull%2C%22max%22%3Anull%7D%2C%22geo_objets%22%3A%5B439%5D%7D; cnil=1; atidvisitor=%7B%22name%22%3A%22atidvisitor%22%2C%22val%22%3A%7B%22vrn%22%3A%22-590496-%22%7D%2C%22options%22%3A%7B%22path%22%3A%22%2F%22%2C%22session%22%3A15724800%2C%22end%22%3A15724800%7D%7D; _ga=GA1.2.1535488843.1566545480; _gid=GA1.2.2016445835.1566545480; _gat=1',
'DNT': '1',
'Sec-Fetch-Mode': 'navigate',
'Sec-Fetch-Site': 'none',
'Sec-Fetch-User': '?1',
'Upgrade-Insecure-Requests': '1',
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36'}

# %%
all_urls = []
for k in range(20):
    url = f'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-{k}'
    html=requests.get(url, headers=headers).content
    time.sleep(2)
    soup=BeautifulSoup(html)
    insideURL = soup.select('div.col-left a[href^="/"]')
    for i in insideURL:
        all_urls.append('https://www.pap.fr' + i.get('href'))
all_urls
# Out:
# ['https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r190706132',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r178610392',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r420801139',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r428601373',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r428500125',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r419400095',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r428700336',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r16290586',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r195104140',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r428700122',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r190706132',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r178610392',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r420801139',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r428601373',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r428500125',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r419400095',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r428700336',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r16290586',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r195104140',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-r428700122',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-2-r195909243',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-2-r414801441',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-2-r428501228',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-2-r427200707',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-2-r424000027',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-2-r424701560',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-2-r428700116',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-2-r197409070',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-2-r419300023',
#  'https://www.pap.fr/annonce/locations-appartement-paris-75-g439-2-r428400259',
#  'https://www.pap.fr/annonce/locations-appartement-particulier-paris-75-g439-3-r175406178',
#  'https://www.pap.fr/annonce/locations-appartement-particulier-paris-75-g439-3-r426100905',
#  'https://www.pap.fr/annonce/locations-appartement-particulier-paris-75-g439-3-r421500312',
#  'https://www.pap.fr/annonce/locations-appartement-particulier-paris-75-g439-3-r426500534',
#  'https://www.pap.fr/annonce/locations-appartement-particulier-paris-75-g439-3-r417100385',
#  'https://www.pap.fr/annonce/locations-appartement-particulier-paris-75-g439-3-r428700574',
#  'https://www.pap.fr/annonce/locations-appartement-particulier-paris-75-g439-3-r428700669',
#  'https://www.pap.fr/annonce/locations-appartement-particulier-paris-75-g439-3-r428700685',
#  'https://www.pap.fr/annonce/locations-appartement-particulier-paris-75-g439-3-r413600650',
#  'https://www.pap.fr/annonce/locations-appartement-particulier-paris-75-g439-3-r427600865',
#  'https://www.pap.fr/annonce/immobilier-location-appartement-paris-75-g439-4-r195304041',
#  'https://www.pap.fr/annonce/immobilier-location-appartement-paris-75-g439-4-r427501311',
#  'https://www.pap.fr/annonce/immobilier-location-appartement-paris-75-g439-4-r197104035',
#  'https://www.pap.fr/annonce/immobilier-location-appartement-paris-75-g439-4-r428700102',
#  'https://www.pap.fr/annonce/immobilier-location-appartement-paris-75-g439-4-r428700679',
#  'https://www.pap.fr/annonce/immobilier-location-appartement-paris-75-g439-4-r428200742',
#  'https://www.pap.fr/annonce/immobilier-location-appartement-paris-75-g439-4-r407801920',
#  'https://www.pap.fr/annonce/immobilier-location-appartement-paris-75-g439-4-r428600098',
#  'https://www.pap.fr/annonce/immobilier-location-appartement-paris-75-g439-4-r417000896',
#  'https://www.pap.fr/annonce/immobilier-location-appartement-paris-75-g439-4-r428000232',
#  'https://www.pap.fr/annonce/locations-d-appartement-paris-75-g439-5-r199010386',
#  'https://www.pap.fr/annonce/locations-d-appartement-paris-75-g439-5-r402402333',
#  'https://www.pap.fr/annonce/locations-d-appartement-paris-75-g439-5-r427201154',
#  'https://www.pap.fr/annonce/locations-d-appartement-paris-75-g439-5-r428400401',
#  'https://www.pap.fr/annonce/locations-d-appartement-paris-75-g439-5-r428601319',
#  'https://www.pap.fr/annonce/locations-d-appartement-paris-75-g439-5-r428600960',
#  'https://www.pap.fr/annonce/locations-d-appartement-paris-75-g439-5-r419200635',
#  'https://www.pap.fr/annonce/locations-d-appartement-paris-75-g439-5-r401401132',
#  'https://www.pap.fr/annonce/locations-d-appartement-paris-75-g439-5-r418900245',
#  'https://www.pap.fr/annonce/locations-d-appartement-paris-75-g439-5-r428600071',
#  'https://www.pap.fr/annonce/location-appart-paris-75-g439-6-r428700481',
#  'https://www.pap.fr/annonce/location-appart-paris-75-g439-6-r426901457',
#  'https://www.pap.fr/annonce/location-appart-paris-75-g439-6-r1991032',
#  'https://www.pap.fr/annonce/location-appart-paris-75-g439-6-r427701358',
#  'https://www.pap.fr/annonce/location-appart-paris-75-g439-6-r420200736',
#  'https://www.pap.fr/annonce/location-appart-paris-75-g439-6-r402901148',
#  'https://www.pap.fr/annonce/location-appart-paris-75-g439-6-r428600164',
#  'https://www.pap.fr/annonce/location-appart-paris-75-g439-6-r428700290',
#  'https://www.pap.fr/annonce/location-appart-paris-75-g439-6-r411601064',
#  'https://www.pap.fr/annonce/location-appart-paris-75-g439-6-r416500727',
#  'https://www.pap.fr/annonce/offre-location-appartement-paris-75-g439-7-r412800353',
#  'https://www.pap.fr/annonce/offre-location-appartement-paris-75-g439-7-r427600298',
#  'https://www.pap.fr/annonce/offre-location-appartement-paris-75-g439-7-r425801483',
#  'https://www.pap.fr/annonce/offre-location-appartement-paris-75-g439-7-r427701146',
#  'https://www.pap.fr/annonce/offre-location-appartement-paris-75-g439-7-r428700470',
#  'https://www.pap.fr/annonce/offre-location-appartement-paris-75-g439-7-r428600537',
#  'https://www.pap.fr/annonce/offre-location-appartement-paris-75-g439-7-r424601229',
#  'https://www.pap.fr/annonce/offre-location-appartement-paris-75-g439-7-r428700657',
#  'https://www.pap.fr/annonce/offre-location-appartement-paris-75-g439-7-r428700653',
#  'https://www.pap.fr/annonce/offre-location-appartement-paris-75-g439-7-r426800532',
#  'https://www.pap.fr/annonce/appartement-a-louer-paris-75-g439-8-r428300269',
#  'https://www.pap.fr/annonce/appartement-a-louer-paris-75-g439-8-r417101316',
#  'https://www.pap.fr/annonce/appartement-a-louer-paris-75-g439-8-r418501202',
#  'https://www.pap.fr/annonce/appartement-a-louer-paris-75-g439-8-r170704016',
#  'https://www.pap.fr/annonce/appartement-a-louer-paris-75-g439-8-r428700649',
#  'https://www.pap.fr/annonce/appartement-a-louer-paris-75-g439-8-r428700644',
#  'https://www.pap.fr/annonce/appartement-a-louer-paris-75-g439-8-r428700642',
#  'https://www.pap.fr/annonce/appartement-a-louer-paris-75-g439-8-r423700685',
#  'https://www.pap.fr/annonce/appartement-a-louer-paris-75-g439-8-r427401154',
#  'https://www.pap.fr/annonce/appartement-a-louer-paris-75-g439-8-r192511049',
#  'https://www.pap.fr/annonce/appartement-en-location-paris-75-g439-9-r192511049',
#  'https://www.pap.fr/annonce/appartement-en-location-paris-75-g439-9-r428400957',
#  'https://www.pap.fr/annonce/appartement-en-location-paris-75-g439-9-r194610000',
#  'https://www.pap.fr/annonce/appartement-en-location-paris-75-g439-9-r415901241',
#  'https://www.pap.fr/annonce/appartement-en-location-paris-75-g439-9-r423400049',
#  'https://www.pap.fr/annonce/appartement-en-location-paris-75-g439-9-r428500599',
#  'https://www.pap.fr/annonce/appartement-en-location-paris-75-g439-9-r428700595',
#  'https://www.pap.fr/annonce/appartement-en-location-paris-75-g439-9-r415201442',
#  'https://www.pap.fr/annonce/appartement-en-location-paris-75-g439-9-r413301086',
#  'https://www.pap.fr/annonce/appartement-en-location-paris-75-g439-9-r427900581',
#  'https://www.pap.fr/annonce/recherche-location-appartement-paris-75-g439-10-r428700131',
#  'https://www.pap.fr/annonce/recherche-location-appartement-paris-75-g439-10-r411402391',
#  'https://www.pap.fr/annonce/recherche-location-appartement-paris-75-g439-10-r428700246',
#  'https://www.pap.fr/annonce/recherche-location-appartement-paris-75-g439-10-r416000128',
#  'https://www.pap.fr/annonce/recherche-location-appartement-paris-75-g439-10-r427200545',
#  'https://www.pap.fr/annonce/recherche-location-appartement-paris-75-g439-10-r428700036',
#  'https://www.pap.fr/annonce/recherche-location-appartement-paris-75-g439-10-r426901002',
#  'https://www.pap.fr/annonce/recherche-location-appartement-paris-75-g439-10-r1915036',
#  'https://www.pap.fr/annonce/recherche-location-appartement-paris-75-g439-10-r427301581',
#  'https://www.pap.fr/annonce/recherche-location-appartement-paris-75-g439-10-r428600503',
#  'https://www.pap.fr/annonce/annonce-location-appartement-paris-75-g439-11-r428700616',
#  'https://www.pap.fr/annonce/annonce-location-appartement-paris-75-g439-11-r428700241',
#  'https://www.pap.fr/annonce/annonce-location-appartement-paris-75-g439-11-r417101292',
#  'https://www.pap.fr/annonce/annonce-location-appartement-paris-75-g439-11-r428700245',
#  'https://www.pap.fr/annonce/annonce-location-appartement-paris-75-g439-11-r406700159',
#  'https://www.pap.fr/annonce/annonce-location-appartement-paris-75-g439-11-r422900068',
#  'https://www.pap.fr/annonce/annonce-location-appartement-paris-75-g439-11-r427800133',
#  'https://www.pap.fr/annonce/annonce-location-appartement-paris-75-g439-11-r191609231',
#  'https://www.pap.fr/annonce/annonce-location-appartement-paris-75-g439-11-r428400497',
#  'https://www.pap.fr/annonce/annonce-location-appartement-paris-75-g439-11-r1966090',
#  'https://www.pap.fr/annonce/annonces-location-appartement-paris-75-g439-12-r178210230',
#  'https://www.pap.fr/annonce/annonces-location-appartement-paris-75-g439-12-r409200847',
#  'https://www.pap.fr/annonce/annonces-location-appartement-paris-75-g439-12-r428700017',
#  'https://www.pap.fr/annonce/annonces-location-appartement-paris-75-g439-12-r428300253',
#  'https://www.pap.fr/annonce/annonces-location-appartement-paris-75-g439-12-r428500145',
#  'https://www.pap.fr/annonce/annonces-location-appartement-paris-75-g439-12-r420201313',
#  'https://www.pap.fr/annonce/annonces-location-appartement-paris-75-g439-12-r419400531',
#  'https://www.pap.fr/annonce/annonces-location-appartement-paris-75-g439-12-r428700623',
#  'https://www.pap.fr/annonce/annonces-location-appartement-paris-75-g439-12-r407500652',
#  'https://www.pap.fr/annonce/annonces-location-appartement-paris-75-g439-12-r428300190',
#  'https://www.pap.fr/annonce/locations-appartement-entre-particuliers-paris-75-g439-13-r407300604',
#  'https://www.pap.fr/annonce/locations-appartement-entre-particuliers-paris-75-g439-13-r426601113',
#  'https://www.pap.fr/annonce/locations-appartement-entre-particuliers-paris-75-g439-13-r419700575',
#  'https://www.pap.fr/annonce/locations-appartement-entre-particuliers-paris-75-g439-13-r428700614',
#  'https://www.pap.fr/annonce/locations-appartement-entre-particuliers-paris-75-g439-13-r428700610',
#  'https://www.pap.fr/annonce/locations-appartement-entre-particuliers-paris-75-g439-13-r428500833',
#  'https://www.pap.fr/annonce/locations-appartement-entre-particuliers-paris-75-g439-13-r17920476',
#  'https://www.pap.fr/annonce/locations-appartement-entre-particuliers-paris-75-g439-13-r428700608',
#  'https://www.pap.fr/annonce/locations-appartement-entre-particuliers-paris-75-g439-13-r416501903',
#  'https://www.pap.fr/annonce/locations-appartement-entre-particuliers-paris-75-g439-13-r428501090',
#  'https://www.pap.fr/annonce/location-appartements-sans-agence-paris-75-g439-14-r418001461',
#  'https://www.pap.fr/annonce/location-appartements-sans-agence-paris-75-g439-14-r421800214',
#  'https://www.pap.fr/annonce/location-appartements-sans-agence-paris-75-g439-14-r428700584',
#  'https://www.pap.fr/annonce/location-appartements-sans-agence-paris-75-g439-14-r428700583',
#  'https://www.pap.fr/annonce/location-appartements-sans-agence-paris-75-g439-14-r428700571',
#  'https://www.pap.fr/annonce/location-appartements-sans-agence-paris-75-g439-14-r428700567',
#  'https://www.pap.fr/annonce/location-appartements-sans-agence-paris-75-g439-14-r406101635',
#  'https://www.pap.fr/annonce/location-appartements-sans-agence-paris-75-g439-14-r406501078',
#  'https://www.pap.fr/annonce/location-appartements-sans-agence-paris-75-g439-14-r422202098',
#  'https://www.pap.fr/annonce/location-appartements-sans-agence-paris-75-g439-14-r428100007',
#  'https://www.pap.fr/annonce/location-appart-particulier-paris-75-g439-15-r418200728',
#  'https://www.pap.fr/annonce/location-appart-particulier-paris-75-g439-15-r1814095',
#  'https://www.pap.fr/annonce/location-appart-particulier-paris-75-g439-15-r409700873',
#  'https://www.pap.fr/annonce/location-appart-particulier-paris-75-g439-15-r418001552',
#  'https://www.pap.fr/annonce/location-appart-particulier-paris-75-g439-15-r417600662',
#  'https://www.pap.fr/annonce/location-appart-particulier-paris-75-g439-15-r428600478',
#  'https://www.pap.fr/annonce/location-appart-particulier-paris-75-g439-15-r418201503',
#  'https://www.pap.fr/annonce/location-appart-particulier-paris-75-g439-15-r428501326',
#  'https://www.pap.fr/annonce/location-appart-particulier-paris-75-g439-15-r426901397',
#  'https://www.pap.fr/annonce/location-appart-particulier-paris-75-g439-15-r428300634',
#  'https://www.pap.fr/annonce/appart-a-louer-paris-75-g439-16-r423901601',
#  'https://www.pap.fr/annonce/appart-a-louer-paris-75-g439-16-r196509937',
#  'https://www.pap.fr/annonce/appart-a-louer-paris-75-g439-16-r418401760',
#  'https://www.pap.fr/annonce/appart-a-louer-paris-75-g439-16-r428300458',
#  'https://www.pap.fr/annonce/appart-a-louer-paris-75-g439-16-r427900836',
#  'https://www.pap.fr/annonce/appart-a-louer-paris-75-g439-16-r428600887',
#  'https://www.pap.fr/annonce/appart-a-louer-paris-75-g439-16-r418600535',
#  'https://www.pap.fr/annonce/appart-a-louer-paris-75-g439-16-r420501031',
#  'https://www.pap.fr/annonce/appart-a-louer-paris-75-g439-16-r199610886',
#  'https://www.pap.fr/annonce/appart-a-louer-paris-75-g439-16-r409600664',
#  'https://www.pap.fr/annonce/recherche-appartement-louer-paris-75-g439-17-r427300243',
#  'https://www.pap.fr/annonce/recherche-appartement-louer-paris-75-g439-17-r428400770',
#  'https://www.pap.fr/annonce/recherche-appartement-louer-paris-75-g439-17-r405101065',
#  'https://www.pap.fr/annonce/recherche-appartement-louer-paris-75-g439-17-r421700003',
#  'https://www.pap.fr/annonce/recherche-appartement-louer-paris-75-g439-17-r428600864',
#  'https://www.pap.fr/annonce/recherche-appartement-louer-paris-75-g439-17-r426500767',
#  'https://www.pap.fr/annonce/recherche-appartement-louer-paris-75-g439-17-r428500551',
#  'https://www.pap.fr/annonce/recherche-appartement-louer-paris-75-g439-17-r428601427',
#  'https://www.pap.fr/annonce/recherche-appartement-louer-paris-75-g439-17-r423201090',
#  'https://www.pap.fr/annonce/recherche-appartement-louer-paris-75-g439-17-r427100732',
#  'https://www.pap.fr/annonce/appartement-a-louer-particulier-paris-75-g439-18-r414500552',
#  'https://www.pap.fr/annonce/appartement-a-louer-particulier-paris-75-g439-18-r428501017',
#  'https://www.pap.fr/annonce/appartement-a-louer-particulier-paris-75-g439-18-r428501020',
#  'https://www.pap.fr/annonce/appartement-a-louer-particulier-paris-75-g439-18-r423300582',
#  'https://www.pap.fr/annonce/appartement-a-louer-particulier-paris-75-g439-18-r428501014',
#  'https://www.pap.fr/annonce/appartement-a-louer-particulier-paris-75-g439-18-r428700558',
#  'https://www.pap.fr/annonce/appartement-a-louer-particulier-paris-75-g439-18-r417201854',
#  'https://www.pap.fr/annonce/appartement-a-louer-particulier-paris-75-g439-18-r427700708',
#  'https://www.pap.fr/annonce/appartement-a-louer-particulier-paris-75-g439-18-r428601029',
#  'https://www.pap.fr/annonce/appartement-a-louer-particulier-paris-75-g439-18-r427001084',
#  'https://www.pap.fr/annonce/offres-location-appartement-paris-75-g439-19-r405502206',
#  'https://www.pap.fr/annonce/offres-location-appartement-paris-75-g439-19-r428600647',
#  'https://www.pap.fr/annonce/offres-location-appartement-paris-75-g439-19-r427201230',
#  'https://www.pap.fr/annonce/offres-location-appartement-paris-75-g439-19-r428300434',
#  'https://www.pap.fr/annonce/offres-location-appartement-paris-75-g439-19-r414000698',
#  'https://www.pap.fr/annonce/offres-location-appartement-paris-75-g439-19-r422900178',
#  'https://www.pap.fr/annonce/offres-location-appartement-paris-75-g439-19-r428401089',
#  'https://www.pap.fr/annonce/offres-location-appartement-paris-75-g439-19-r428000909',
#  'https://www.pap.fr/annonce/offres-location-appartement-paris-75-g439-19-r423500188',
#  'https://www.pap.fr/annonce/offres-location-appartement-paris-75-g439-19-r428700166']

# %%
headers2={'cookie': 'CONSENT=YES+FR.fr+20150705-15-0; ANID=OPT_OUT; HSID=ApMZAbapSTFtlMuMc; SSID=AfdK8DH3W3B76td3F; APISID=q2s604BHb2h-jr28/AsAkBvzWdOcaN4amn; SAPISID=qSJnlVdi1hWcvJLD/ANJqiu1fuWteInXTO; SID=mQccDQB719xk7SO8Iizjgi7PmTvXKjKJI0BZUWUnKjHUMq4x3j-jARkLyv199ERnRgxaRQ.; NID=188=kAsVBKfNVfW8lROy9e0a-U0h3B7GC3D-A2VHLriyIwJBEukWaPRCxt6AHbqmSJMtdGVEW7soQfnaMZhYs6xkxYHSSA5cl4T0ElB-1BVDX7TlmQFkGp2D1USF4XiFOHucpVAaQpUvSQQgoa7l49f6Gqs8hbiQwro1QFkzRJpT5cu3Kyk7cTfXD87JSlrp5TDbn8REkkv1pku7es3QSzPs-8Tba93KB71GYHg1lMH4bMbypbQ; 1P_JAR=2019-8-23-9; SIDCC=AN0-TYvsTQuVD_D5Xd9b6AtxU_5vWmrkoguZ_wQoQfS78Ax8VfftJDDFAdF4ja81NLMfFN-ubg',
'dnt': '1',
'sec-fetch-mode':'cors',
'sec-fetch-site':'same-origin',
'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36',
'x-client-data': 'CJK2yQEIorbJAQjEtskBCKmdygEIqKPKAQjiqMoBCI6rygEIl63KAQjNrcoBCPKtygEIzK7KAQjKr8oB'}
names_price = []
date=[]
description=[]
for i in all_urls:
    html=requests.get(i,headers=headers2).content
    time.sleep(2)
    soup=BeautifulSoup(html)
    titles = [i.text for i in soup.select('h1,p')]
    names_price.append(titles[0])
    date.append(titles[1])
    description.append(titles[2])

# %%
import pandas as pd
names_prices=pd.DataFrame(names_price)
dates=pd.DataFrame(date)
descriptions=pd.DataFrame(description)
data=pd.concat([names_prices, dates, descriptions],axis=1)
data.columns = ['Title','Date','Description']
data.head()
# Out:
#                                                Title  \
# 0  \n\t\t\t\tLocation appartement 3 pièces 79 m² ...
# 1  \n\t\t\t\tLocation meublée studio 33 m² Paris ...
# 2  \n\t\t\t\tLocation appartement 2 pièces 57 m² ...
# 3  \n\t\t\t\tLocation meublée appartement 3 pièce...
# 4  \n\t\t\t\tLocation meublée appartement 2 pièce...
#
#                                    Date  \
# 0  Réf. : 907/6132 /  13 septembre 2019
# 1  Réf. : 786/A392 /  13 septembre 2019
# 2  Réf. : C08/1139 /  13 septembre 2019
# 3  Réf. : C86/1373 /  13 septembre 2019
# 4  Réf. : C85/0125 /  13 septembre 2019
#
#                                          Description
# 0  Location vide.\n\r\nAppartement 3 pièces de 79...
# 1  \n\t\t\t\t\tGrand studio moderne entre Montpar...
# 2  Appartement 2 pièces de 57 m², quartier Exelma...
# 3  Très agréable appartement dans un bel immeuble...
# 4  Quartier Latin / Les Gobelins  - 33m2.\n\r\nMa...

# %%
title_list=[i.strip().replace('\xa0', '').replace('\t', ' ').lstrip('Location') for i in data.Title.tolist()]

# %%
import re
price_list=[]
for i in title_list:
    try:
        match=re.search(r'(\d?\.?\d+)€', i).group(1)
    except:
        match='-1'
    price_list.append(match)

price_list1=[int(i.replace('.','')) for i in price_list]
# Out:
# [1990,
#  1320,
#  1520,
#  2900,
#  1590,
#  1250,
#  2390,
#  2370,
#  1100,
#  1600,
#  1990,
#  1320,
#  1520,
#  2900,
#  1590,
#  1250,
#  2390,
#  2370,
#  1100,
#  1600,
#  1250,
#  1435,
#  2100,
#  1110,
#  1280,
#  441,
#  830,
#  1900,
#  780,
#  1097,
#  900,
#  1890,
#  575,
#  675,
#  485,
#  890,
#  900,
#  1150,
#  900,
#  1090,
#  1085,
#  1550,
#  1100,
#  1820,
#  750,
#  1149,
#  1800,
#  2200,
#  1350,
#  1950,
#  2180,
#  2680,
#  1700,
#  2350,
#  4100,
#  2610,
#  675,
#  850,
#  690,
#  940,
#  980,
#  1700,
#  720,
#  3600,
#  1990,
#  1750,
#  1900,
#  1120,
#  530,
#  760,
#  2850,
#  600,
#  2370,
#  2350,
#  615,
#  1258,
#  1200,
#  850,
#  650,
#  900,
#  850,
#  1980,
#  1080,
#  1068,
#  850,
#  900,
#  2460,
#  2950,
#  1290,
#  1400,
#  1400,
#  2800,
#  1375,
#  1600,
#  750,
#  450,
#  1000,
#  950,
#  958,
#  1660,
#  1100,
#  1497,
#  835,
#  1150,
#  1950,
#  1293,
#  1060,
#  1597,
#  1575,
#  1490,
#  1150,
#  1200,
#  1030,
#  2950,
#  2900,
#  1150,
#  980,
#  900,
#  1180,
#  1850,
#  690,
#  900,
#  1500,
#  1400,
#  1600,
#  950,
#  1460,
#  720,
#  800,
#  1240,
#  595,
#  1750,
#  960,
#  2950,
#  640,
#  1565,
#  1200,
#  2000,
#  1800,
#  760,
#  1500,
#  2300,
#  520,
#  1100,
#  902,
#  1100,
#  1540,
#  1110,
#  2290,
#  2500,
#  1850,
#  1700,
#  920,
#  1550,
#  900,
#  1020,
#  1000,
#  1160,
#  1950,
#  2400,
#  700,
#  2390,
#  840,
#  1030,
#  1350,
#  1110,
#  1090,
#  2770,
#  1240,
#  1580,
#  2400,
#  1500,
#  1840,
#  1195,
#  1590,
#  470,
#  1590,
#  2960,
#  950,
#  1400,
#  1599,
#  600,
#  650,
#  1700,
#  983,
#  875,
#  2850,
#  1780,
#  2000,
#  1265,
#  690,
#  980,
#  1850,
#  1000,
#  700,
#  2905,
#  1950,
#  2280,
#  3700,
#  1700]

# %%
location=[]
for i in title_list:
    try:
        match=re.search(r'Paris [\d+\w+]*', i).group(0)
    except:
        match='-1'
    location.append(match)

# %%
m2=[]
for i in title_list:
    try:
        match=re.search(r'\d+m', i).group(0)
    except:
        match='-1'
    m2.append(match)

# %%
description=[title_list[i].replace(price_list[i],'').strip('€ ').replace(location[i],'').replace(m2[i],'').replace(' ² ',' 1').replace('é', 'e') for i in range(len(title_list))]
loc_type=[]
for i in description:
    try:
        match=re.search(r'^\s*\D*', i).group(0)
    except:
        match='-1'
    loc_type.append(match)

# %%
import re
loc_date=[]
for i in date:
    try:
        match=re.findall(r"\/  \d\d\D*\d*", str(i))
    except:
        match='-1'
    loc_date.append(match)

# %%
price=pd.DataFrame(price_list)
localisation=pd.DataFrame(location)
surface=pd.DataFrame(m2)
type_appart=pd.DataFrame(loc_type)
date=pd.DataFrame(loc_date)
location_data1=pd.concat([type_appart,surface,price,localisation,date,descriptions], axis=1)
location_data1.columns=['Type_appart','Surface m²','Price €','Localisation','Date Post','Description']
location_data1.head()
# Out:
#             Type_appart Surface m² Price € Localisation             Date Post  \
# 0          appartement         79m   1.990    Paris 17E  /  13 septembre 2019
# 1       meublee studio         33m   1.320    Paris 14E  /  13 septembre 2019
# 2          appartement         57m   1.520    Paris 16E  /  13 septembre 2019
# 3  meublee appartement         76m   2.900    Paris 16E  /  13 septembre 2019
# 4  meublee appartement         33m   1.590     Paris 5E  /  13 septembre 2019
#
#                                          Description
# 0  Location vide.\n\r\nAppartement 3 pièces de 79...
# 1  \n\t\t\t\t\tGrand studio moderne entre Montpar...
# 2  Appartement 2 pièces de 57 m², quartier Exelma...
# 3  Très agréable appartement dans un bel immeuble...
# 4  Quartier Latin / Les Gobelins  - 33m2.\n\r\nMa...

# %%
location_data1.to_csv('PAP_data1309_forcomp0609.csv')
